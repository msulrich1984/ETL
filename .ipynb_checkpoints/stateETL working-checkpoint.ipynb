# %%
import pandas as pd
from sqlalchemy import create_engine  #Store CSV into DataFrame
import json

import pprint

# %%
csv_file = "population.csv"
pop_data_df = pd.read_csv(csv_file)
pop_data_df
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  ESTIMATESBASE2010  \
# 0       10      0        0      0         United States          308758105
# 1       20      1        0      0      Northeast Region           55318430
# 2       20      2        0      0        Midwest Region           66929743
# 3       20      3        0      0          South Region          114563045
# 4       20      4        0      0           West Region           71946887
# 5       40      3        6      1               Alabama            4780138
# 6       40      4        9      2                Alaska             710249
# 7       40      4        8      4               Arizona            6392288
# 8       40      3        7      5              Arkansas            2916028
# 9       40      4        9      6            California           37254523
# 10      40      4        8      8              Colorado            5029316
# ...

# %%
#data=json.load(open('state_sociological.json'))
#with open(data) as jsonfile:
#    state_sociological_df=pd.read_json(jsonfile)
#text=data.read()
state_json = json.load(open('state_sociological.json'))
#text = print(data)
#print json.dumps(data, indent=4)

# %%
state_json
# Out:
# {'data': [{'state': 'Massachusetts',
#    'percent_educational_attainment': 38.2,
#    'percent_peace_index': 59.92,
#    'percent_above_poverty_rate': 88.3,
#    'percent_non_religious': 67},
#   {'state': 'Maryland',
#    'percent_educational_attainment': 37.3,
#    'percent_peace_index': 37.1,
#    'percent_above_poverty_rate': 89.6,
#    'percent_non_religious': 46},
#   {'state': 'Colorado',
#    'percent_educational_attainment': 35.9,
#    'percent_peace_index': 49.48,
#    'percent_above_poverty_rate': 87.9,
#    'percent_non_religious': 53},
#   {'state': 'Connecticut',
#    'percent_educational_attainment': 35.6,
#    'percent_peace_index': 56.12,
#    'percent_above_poverty_rate': 89.2,
#    'percent_non_religious': 57},
#   {'state': 'New Jersey',
#    'percent_educational_attainment': 34.5,
#    'percent_peace_index': 47.38,
#    'percent_above_poverty_rate': 88.9,
#    'percent_non_religious': 45},
#   {'state': 'Virginia',
#    'percent_educational_attainment': 34,
# ...

# %%
state_df = pd.DataFrame(state_json["data"])
state_df
# Out:
#     percent_above_poverty_rate  percent_educational_attainment  \
# 0                         88.3                            38.2
# 1                         89.6                            37.3
# 2                         87.9                            35.9
# 3                         89.2                            35.6
# 4                         88.9                            34.5
# 5                         88.2                            34.0
# 6                         87.8                            33.1
# 7                         84.1                            32.4
# 8                         90.8                            32.0
# 9                         88.6                            31.5
# 10                        86.8                            31.0
# 11                        85.7                            30.6
# 12                        85.2                            30.5
# 13                        83.6                            29.9
# ...

# %%
renamed_df = pop_data_df.rename(columns={"NAME":"state", "STATE":"index"})
renamed_df.head()
# Out:
#    SUMLEV REGION DIVISION  index             state  ESTIMATESBASE2010  \
# 0      10      0        0      0     United States          308758105
# 1      20      1        0      0  Northeast Region           55318430
# 2      20      2        0      0    Midwest Region           66929743
# 3      20      3        0      0      South Region          114563045
# 4      20      4        0      0       West Region           71946887
#
#    POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0        309326085        311580009        313874218        316057727
# 1         55380645         55600532         55776729         55907823
# 2         66974749         67152631         67336937         67564135
# 3        114867066        116039399        117271075        118393244
# 4         72103625         72787447         73489477         74192525
#
#         ...         NRANK_NPCHG2018  NRANK_PPCHG2010  NRANK_PPCHG2011  \
# ...

# %%
pd.merge(state_df, renamed_df,)
df = pd.merge(state_df,renamed_df[['state','POPESTIMATE2016']], how='left')
df.head()
# Out:
#    percent_above_poverty_rate  percent_educational_attainment  \
# 0                        88.3                            38.2
# 1                        89.6                            37.3
# 2                        87.9                            35.9
# 3                        89.2                            35.6
# 4                        88.9                            34.5
#
#    percent_non_religious  percent_peace_index          state  POPESTIMATE2016
# 0                     67                59.92  Massachusetts          6826022
# 1                     46                37.10       Maryland          6004692
# 2                     53                49.48       Colorado          5540921
# 3                     57                56.12    Connecticut          3578674
# 4                     45                47.38     New Jersey          8874516

# %%
# PyMySQL 
import pymysql
from pandas.io import sql
import MySQLdb

pymysql.install_as_MySQLdb()
engine = create_engine("mysql://root:Primavera01@localhost/StateETL")

df.to_sql(con=engine, name='state_info', if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     790         if not fairy:
# --> 791             fairy = _ConnectionRecord.checkout(pool)
#     792
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# ...
